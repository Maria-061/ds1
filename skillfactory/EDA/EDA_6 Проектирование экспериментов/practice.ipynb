# %%
# импорт библиотек
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from comet_ml import Experiment

# %%
# Создание эксперимента 
experiment = Experiment(
    api_key='6aRchcnElXpdZ0ULHn8sY4EaN',
    project_name='medical-appointment',
    workspace='maria-061',
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/maria-061/medical-appointment/fcfbec37576d4040af029d115722cefa

# %%
# загрузка данных
numeric_data = pd.read_csv('data/KaggleV2-May-2016.csv')

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
# удаление признаков
numeric_data.drop(['AppointmentID', 'PatientId', 'ScheduledDay', 'AppointmentDay', 'No-show', 'Gender', 'Neighbourhood'], axis=1, inplace = True)

# %%
sns.heatmap(numeric_data.corr(), annot=True)
# логирование графике в Comet
experiment.log_figure(figure=plt)
# Out:
# {'web': 'https://www.comet.com/api/image/download?imageId=83c9d0c80baf49f8a25dff9c20b8c213&experimentKey=fcfbec37576d4040af029d115722cefa',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=83c9d0c80baf49f8a25dff9c20b8c213&experimentKey=fcfbec37576d4040af029d115722cefa',
#  'imageId': '83c9d0c80baf49f8a25dff9c20b8c213'}

# %% [markdown]
# **Вывод:** Корреляция практически во всех случаях близка к нулю, что говорит о том, что признаки не коррелируют, т.е. взаимосвязи нет.
# Есть небольшая положительная взаимосвязь между признаками "Повышенное напряжение" и "Возраст" и "Наличие сахарного диабета", что вполне нормально.

# %%
# логирование графике в Comet
experiment.log_figure(figure=plt)
# Out:
# COMET WARNING: Refuse to upload empty figure, please call log_figure before calling show
# COMET WARNING: Failing to save the matplotlib figure
