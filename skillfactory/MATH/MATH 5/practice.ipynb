# %%
def f(x,y,z):
    return x**3-2*(x**2)+y**2+z**2-2*x*y+x*z-y*z+3*z
def grad(x, y, z):
    dx=3*(x**2)-4*x-2*y+z  
    dy=2*y-2*x-z
    dz=2*z+x-y+3
    return (dx, dy, dz)

# %%
x0=(1, 2, 1)
gamma=0.1
x_cur=x0

i=1

while True:
    x_new=(x_cur[0]-gamma*grad(*x_cur)[0],
           x_cur[1]-gamma*grad(*x_cur)[1],
           x_cur[2]-gamma*grad(*x_cur)[2])
    if i > 200:
        break
    x_cur=x_new
    i+=1
    print(f"iter={i}; x=({x_cur[0]:.2f}, {x_cur[1]:.2f}, {x_cur[2]:.2f});"
          f" f(x)={f(*x_cur):.2f}; grad f(x)=({grad(*x_cur)[0]:.2f}, {grad(*x_cur)[1]:.2f}, {grad(*x_cur)[2]:.2f})")
# Out:
# iter=2; x=(1.40, 1.90, 0.60); f(x)=-1.03; grad f(x)=(-2.92, 0.40, 3.70)
# iter=3; x=(1.69, 1.86, 0.23); f(x)=-3.01; grad f(x)=(-1.67, 0.11, 3.29)
# iter=4; x=(1.86, 1.85, -0.10); f(x)=-4.23; grad f(x)=(-0.87, 0.08, 2.81)
# iter=5; x=(1.95, 1.84, -0.38); f(x)=-5.02; grad f(x)=(-0.49, 0.17, 2.34)
# iter=6; x=(1.99, 1.82, -0.61); f(x)=-5.54; grad f(x)=(-0.31, 0.27, 1.94)
# iter=7; x=(2.03, 1.80, -0.81); f(x)=-5.90; grad f(x)=(-0.20, 0.35, 1.61)
# iter=8; x=(2.05, 1.76, -0.97); f(x)=-6.16; grad f(x)=(-0.13, 0.40, 1.34)
# iter=9; x=(2.06, 1.72, -1.10); f(x)=-6.34; grad f(x)=(-0.08, 0.43, 1.13)
# iter=10; x=(2.07, 1.68, -1.22); f(x)=-6.48; grad f(x)=(-0.04, 0.44, 0.95)
# iter=11; x=(2.07, 1.63, -1.31); f(x)=-6.58; grad f(x)=(-0.01, 0.44, 0.81)
# iter=12; x=(2.07, 1.59, -1.39); f(x)=-6.66; grad f(x)=(0.01, 0.43, 0.69)
# iter=13; x=(2.07, 1.55, -1.46); f(x)=-6.73; grad f(x)=(0.02, 0.42, 0.60)
# iter=14; x=(2.07, 1.50, -1.52); f(x)=-6.78; grad f(x)=(0.03, 0.40, 0.52)
# iter=15; x=(2.07, 1.47, -1.57); f(x)=-6.82; grad f(x)=(0.03, 0.37, 0.45)
# iter=16; x=(2.06, 1.43, -1.62); f(x)=-6.85; grad f(x)=(0.03, 0.35, 0.40)
# iter=17; x=(2.06, 1.39, -1.66); f(x)=-6.88; grad f(x)=(0.04, 0.33, 0.35)
# iter=18; x=(2.06, 1.36, -1.69); f(x)=-6.90; grad f(x)=(0.04, 0.30, 0.31)
# iter=19; x=(2.05, 1.33, -1.72); f(x)=-6.92; grad f(x)=(0.04, 0.28, 0.27)
# iter=20; x=(2.05, 1.30, -1.75); f(x)=-6.93; grad f(x)=(0.04, 0.26, 0.24)
# iter=21; x=(2.04, 1.28, -1.78); f(x)=-6.94; grad f(x)=(0.03, 0.24, 0.22)
# iter=22; x=(2.04, 1.25, -1.80); f(x)=-6.95; grad f(x)=(0.03, 0.22, 0.19)
# iter=23; x=(2.04, 1.23, -1.82); f(x)=-6.96; grad f(x)=(0.03, 0.20, 0.17)
# iter=24; x=(2.03, 1.21, -1.83); f(x)=-6.97; grad f(x)=(0.03, 0.18, 0.16)
# iter=25; x=(2.03, 1.19, -1.85); f(x)=-6.97; grad f(x)=(0.03, 0.17, 0.14)
# iter=26; x=(2.03, 1.17, -1.86); f(x)=-6.98; grad f(x)=(0.02, 0.15, 0.13)
# iter=27; x=(2.03, 1.16, -1.88); f(x)=-6.98; grad f(x)=(0.02, 0.14, 0.11)
# iter=28; x=(2.02, 1.14, -1.89); f(x)=-6.98; grad f(x)=(0.02, 0.13, 0.10)
# iter=29; x=(2.02, 1.13, -1.90); f(x)=-6.99; grad f(x)=(0.02, 0.12, 0.09)
# iter=30; x=(2.02, 1.12, -1.91); f(x)=-6.99; grad f(x)=(0.02, 0.11, 0.08)
# iter=31; x=(2.02, 1.11, -1.92); f(x)=-6.99; grad f(x)=(0.02, 0.10, 0.08)
# iter=32; x=(2.02, 1.10, -1.92); f(x)=-6.99; grad f(x)=(0.01, 0.09, 0.07)
# iter=33; x=(2.02, 1.09, -1.93); f(x)=-6.99; grad f(x)=(0.01, 0.08, 0.06)
# iter=34; x=(2.01, 1.08, -1.94); f(x)=-7.00; grad f(x)=(0.01, 0.07, 0.06)
# iter=35; x=(2.01, 1.08, -1.94); f(x)=-7.00; grad f(x)=(0.01, 0.07, 0.05)
# iter=36; x=(2.01, 1.07, -1.95); f(x)=-7.00; grad f(x)=(0.01, 0.06, 0.05)
# iter=37; x=(2.01, 1.06, -1.95); f(x)=-7.00; grad f(x)=(0.01, 0.06, 0.04)
# iter=38; x=(2.01, 1.06, -1.96); f(x)=-7.00; grad f(x)=(0.01, 0.05, 0.04)
# iter=39; x=(2.01, 1.05, -1.96); f(x)=-7.00; grad f(x)=(0.01, 0.05, 0.04)
# iter=40; x=(2.01, 1.05, -1.96); f(x)=-7.00; grad f(x)=(0.01, 0.04, 0.03)
# iter=41; x=(2.01, 1.04, -1.97); f(x)=-7.00; grad f(x)=(0.01, 0.04, 0.03)
# iter=42; x=(2.01, 1.04, -1.97); f(x)=-7.00; grad f(x)=(0.01, 0.04, 0.03)
# iter=43; x=(2.01, 1.04, -1.97); f(x)=-7.00; grad f(x)=(0.01, 0.03, 0.02)
# iter=44; x=(2.01, 1.03, -1.98); f(x)=-7.00; grad f(x)=(0.01, 0.03, 0.02)
# iter=45; x=(2.01, 1.03, -1.98); f(x)=-7.00; grad f(x)=(0.00, 0.03, 0.02)
# iter=46; x=(2.00, 1.03, -1.98); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.02)
# iter=47; x=(2.00, 1.02, -1.98); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.02)
# iter=48; x=(2.00, 1.02, -1.98); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.01)
# iter=49; x=(2.00, 1.02, -1.98); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.01)
# iter=50; x=(2.00, 1.02, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.01)
# iter=51; x=(2.00, 1.02, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.02, 0.01)
# iter=52; x=(2.00, 1.02, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=53; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=54; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=55; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=56; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=57; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=58; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=59; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.01)
# iter=60; x=(2.00, 1.01, -1.99); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.00)
# iter=61; x=(2.00, 1.01, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.00)
# iter=62; x=(2.00, 1.01, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.01, 0.00)
# iter=63; x=(2.00, 1.01, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=64; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=65; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=66; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=67; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=68; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=69; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=70; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=71; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=72; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=73; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=74; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=75; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=76; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=77; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=78; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=79; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=80; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=81; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=82; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=83; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=84; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=85; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=86; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=87; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=88; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=89; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=90; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=91; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=92; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=93; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=94; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=95; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=96; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=97; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=98; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=99; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=100; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=101; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=102; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=103; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=104; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=105; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=106; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=107; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=108; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=109; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=110; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=111; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=112; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=113; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=114; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=115; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=116; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=117; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=118; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=119; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=120; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=121; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=122; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=123; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=124; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=125; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=126; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=127; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=128; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=129; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=130; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=131; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=132; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=133; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=134; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=135; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=136; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=137; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=138; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=139; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=140; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=141; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=142; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=143; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=144; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=145; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=146; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=147; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=148; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=149; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=150; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=151; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=152; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=153; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=154; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=155; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=156; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=157; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=158; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=159; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=160; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=161; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=162; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=163; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=164; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=165; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=166; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=167; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=168; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=169; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=170; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=171; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=172; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=173; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=174; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=175; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=176; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=177; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=178; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=179; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=180; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=181; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=182; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=183; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=184; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=185; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=186; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=187; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=188; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=189; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=190; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=191; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=192; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=193; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=194; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=195; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=196; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=197; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=198; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=199; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=200; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
# iter=201; x=(2.00, 1.00, -2.00); f(x)=-7.00; grad f(x)=(0.00, 0.00, 0.00)
